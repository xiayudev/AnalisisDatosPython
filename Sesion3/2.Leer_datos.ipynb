# %%
pip install "pymongo[srv]"
# Out:
# Collecting pymongo[srv]
#   Downloading pymongo-4.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# WARNING: pymongo 4.10.1 does not provide the extra 'srv'
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo[srv])
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
# Downloading pymongo-4.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 39.8 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.10.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sqlalchemy
# Out:
# Collecting sqlalchemy
#   Downloading SQLAlchemy-2.0.37-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Collecting greenlet!=0.4.17 (from sqlalchemy)
#   Downloading greenlet-3.1.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/codespace/.local/lib/python3.12/site-packages (from sqlalchemy) (4.12.2)
# Downloading SQLAlchemy-2.0.37-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 43.8 MB/s eta 0:00:00
# Downloading greenlet-3.1.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (613 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.1/613.1 kB 28.9 MB/s eta 0:00:00
# Installing collected packages: greenlet, sqlalchemy
# Successfully installed greenlet-3.1.1 sqlalchemy-2.0.37
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mysqlclient
# Out:
# Collecting mysqlclient
#   Downloading mysqlclient-2.2.7.tar.gz (91 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: mysqlclient
#   Building wheel for mysqlclient (pyproject.toml) ... done
#   Created wheel for mysqlclient: filename=mysqlclient-2.2.7-cp312-cp312-linux_x86_64.whl size=136732 sha256=e813f1d40a243fb291f166e6a0fc0a8580ac8377a6b5e66328a44266c63c1770
#   Stored in directory: /home/codespace/.cache/pip/wheels/27/95/18/7f176fffd46629e710c04c810b9c4d7d4358fe7c96a7d2306d
# Successfully built mysqlclient
# Installing collected packages: mysqlclient
# Successfully installed mysqlclient-2.2.7
# Note: you may need to restart the kernel to use updated packages.

# %%
import sqlalchemy as db
from sqlalchemy import text
import pandas as pd

# %%
engine = db.create_engine('mysql://root:root@127.0.0.1:3310/retail_db')
conn = engine.connect()

# %%
customers_df = pd.read_sql_query('SELECT * FROM customers', con=conn)

customers_df
# Out:
#        customer_id customer_fname customer_lname customer_email  \
# 0                1        Richard      Hernandez      XXXXXXXXX
# 1                2           Mary        Barrett      XXXXXXXXX
# 2                3            Ann          Smith      XXXXXXXXX
# 3                4           Mary          Jones      XXXXXXXXX
# 4                5         Robert         Hudson      XXXXXXXXX
# ...            ...            ...            ...            ...
# 12430        12431           Mary           Rios      XXXXXXXXX
# 12431        12432         Angela          Smith      XXXXXXXXX
# 12432        12433       Benjamin         Garcia      XXXXXXXXX
# 12433        12434           Mary          Mills      XXXXXXXXX
# 12434        12435          Laura         Horton      XXXXXXXXX
#
#       customer_password             customer_street customer_city  \
# 0             XXXXXXXXX          6303 Heather Plaza   Brownsville
# 1             XXXXXXXXX     9526 Noble Embers Ridge     Littleton
# 2             XXXXXXXXX      3422 Blue Pioneer Bend        Caguas
# 3             XXXXXXXXX          8324 Little Common    San Marcos
# 4             XXXXXXXXX      10 Crystal River Mall         Caguas
# ...                 ...                         ...           ...
# 12430         XXXXXXXXX           1221 Cinder Pines       Kaneohe
# 12431         XXXXXXXXX  1525 Jagged Barn Highlands        Caguas
# 12432         XXXXXXXXX    5459 Noble Brook Landing     Levittown
# 12433         XXXXXXXXX        9720 Colonial Parade        Caguas
# 12434         XXXXXXXXX            5736 Honey Downs   Summerville
#
#       customer_state customer_zipcode
# 0                 TX            78521
# 1                 CO            80126
# 2                 PR            00725
# 3                 CA            92069
# 4                 PR            00725
# ...              ...              ...
# 12430             HI            96744
# 12431             PR            00725
# 12432             NY            11756
# 12433             PR            00725
# 12434             SC            29483
#
# [12435 rows x 9 columns]

# %%
from pymongo import MongoClient
connection_string = 'mongodb+srv://jctuesta7:XzSZO1nH0mcAdNkJ@cluster0.lfx8q.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'
client = MongoClient(connection_string)

# %%
colection = client['sample_mflix']['embedded_movies']

cursor = colection.find({})

df = pd.DataFrame(cursor)

df
# Out:
#                            _id  \
# 0     573a1390f29313caabcd5293
# 1     573a1391f29313caabcd68d0
# 2     573a1391f29313caabcd820b
# 3     573a1391f29313caabcd8268
# 4     573a1391f29313caabcd8319
# ...                        ...
# 3478  573a13f3f29313caabddfd80
# 3479  573a13f3f29313caabddfde0
# 3480  573a13f5f29313caabde3a5f
# 3481  573a13f7f29313caabde5fa9
# 3482  573a13f7f29313caabde65b4
#
#                                                    plot  \
# 0     Young Pauline is left a lot of money when her ...
# 1     A penniless young man tries to save an heiress...
# 2     Michael "Beau" Geste leaves England in disgrac...
# 3     Seeking revenge, an athletic young man joins t...
# 4     An irresponsible young millionaire changes his...
# ...                                                 ...
# 3478                                                NaN
# 3479  Two siblings discover a supernatural escape fr...
# 3480  Mizuki's husband (Yusuke) drowned at sea three...
# 3481  Away from home, living alone in an old and glo...
# 3482  Our figurine sized supermen hero embarks on an...
#
#                              genres  runtime  \
# 0                          [Action]    199.0
# 1           [Comedy, Short, Action]     22.0
# 2        [Action, Adventure, Drama]    101.0
# 3               [Adventure, Action]     88.0
# 4         [Action, Comedy, Romance]     58.0
# ...                             ...      ...
# 3478       [Comedy, Drama, Fantasy]    119.0
# 3479     [Drama, Fantasy, Thriller]     90.0
# 3480      [Drama, Fantasy, Romance]    127.0
# 3481   [Fantasy, Mystery, Thriller]     62.0
# 3482  [Adventure, Fantasy, Mystery]     68.0
#
#                                                    cast  num_mflix_comments  \
# 0     [Pearl White, Crane Wilbur, Paul Panzer, Edwar...                   0
# 1     [Harold Lloyd, Mildred Davis, 'Snub' Pollard, ...                   0
# 2     [Ronald Colman, Neil Hamilton, Ralph Forbes, A...                   0
# 3     [Billie Dove, Tempe Pigott, Donald Crisp, Sam ...                   1
# 4     [Harold Lloyd, Jobyna Ralston, Noah Young, Jim...                   0
# ...                                                 ...                 ...
# 3478  [Vivian Sung, Bruce Lu-Si Bu, Megan Lai, Li-An...                   0
# 3479  [Kiernan Shipka, Timothèe Chalamet, Elizabeth ...                   0
# 3480  [Eri Fukatsu, Tadanobu Asano, Masaaki Akahori,...                   1
# 3481               [Ticiana Augusto Lima, Guto Parente]                   0
# 3482                   [Daniel Tadesse, Selam Tesfayie]                   0
#
#                                                  poster  \
# 0     https://m.media-amazon.com/images/M/MV5BMzgxOD...
# 1     https://m.media-amazon.com/images/M/MV5BNzE1OW...
# 2                                                   NaN
# 3     https://m.media-amazon.com/images/M/MV5BMzU0ND...
# 4     https://m.media-amazon.com/images/M/MV5BMTcxMT...
# ...                                                 ...
# 3478                                                NaN
# 3479  https://m.media-amazon.com/images/M/MV5BMDkyNW...
# 3480  https://m.media-amazon.com/images/M/MV5BMTJlOT...
# 3481  https://m.media-amazon.com/images/M/MV5BODY4ZT...
# 3482                                                NaN
#
#                                title  \
# 0              The Perils of Pauline
# 1                 From Hand to Mouth
# 2                         Beau Geste
# 3                   The Black Pirate
# 4                  For Heaven's Sake
# ...                              ...
# 3478             Cafè. Waiting. Love
# 3479                     One and Two
# 3480            Journey to the Shore
# 3481  The Mysterious Death of Pèrola
# 3482                          Crumbs
#
#                                                fullplot             languages  \
# 0     Young Pauline is left a lot of money when her ...             [English]
# 1     As a penniless man worries about how he will m...             [English]
# 2     Michael "Beau" Geste leaves England in disgrac...             [English]
# 3     A nobleman vows to avenge the death of his fat...                   NaN
# 4     The Uptown Boy, J. Harold Manners (Lloyd) is a...             [English]
# ...                                                 ...                   ...
# 3478                                                NaN            [Mandarin]
# 3479  Zac and Eva live with their parents in isolate...             [English]
# 3480  Mizuki's husband (Yusuke) drowned at sea three...            [Japanese]
# 3481  Away from home, living alone in an old and glo...  [French, Portuguese]
# 3482  Crumbs is a Spanish-Ethiopian Since fictional ...  [Amharic, Afrikaans]
#
#       ...                                             awards  \
# 0     ...    {'wins': 1, 'nominations': 0, 'text': '1 win.'}
# 1     ...  {'wins': 0, 'nominations': 1, 'text': '1 nomin...
# 2     ...    {'wins': 1, 'nominations': 0, 'text': '1 win.'}
# 3     ...    {'wins': 1, 'nominations': 0, 'text': '1 win.'}
# 4     ...  {'wins': 0, 'nominations': 1, 'text': '1 nomin...
# ...   ...                                                ...
# 3478  ...  {'wins': 0, 'nominations': 1, 'text': '1 nomin...
# 3479  ...  {'wins': 0, 'nominations': 1, 'text': '1 nomin...
# 3480  ...  {'wins': 1, 'nominations': 2, 'text': '1 win &...
# 3481  ...  {'wins': 1, 'nominations': 1, 'text': '1 win &...
# 3482  ...  {'wins': 2, 'nominations': 5, 'text': '2 wins ...
#
#                         lastupdated  year  \
# 0     2015-09-12 00:01:18.647000000  1914
# 1     2015-04-17 00:16:14.220000000  1919
# 2     2015-08-25 00:40:54.383000000  1926
# 3     2015-08-22 01:10:11.970000000  1926
# 4     2015-08-19 00:35:01.953000000  1926
# ...                             ...   ...
# 3478  2015-09-11 00:35:00.010000000  2014
# 3479  2015-09-04 00:10:45.303000000  2015
# 3480  2015-09-11 00:00:26.287000000  2015
# 3481  2015-09-14 08:37:40.413000000  2014
# 3482  2015-09-06 00:05:01.353000000  2015
#
#                                               imdb  \
# 0        {'rating': 7.6, 'votes': 744, 'id': 4465}
# 1       {'rating': 7.0, 'votes': 639, 'id': 10146}
# 2       {'rating': 6.9, 'votes': 222, 'id': 16634}
# 3      {'rating': 7.2, 'votes': 1146, 'id': 16654}
# 4       {'rating': 7.6, 'votes': 918, 'id': 16895}
# ...                                            ...
# 3478  {'rating': 6.8, 'votes': 462, 'id': 3974790}
# 3479  {'rating': 5.5, 'votes': 261, 'id': 3975510}
# 3480   {'rating': 5.2, 'votes': 63, 'id': 4173478}
# 3481   {'rating': 7.1, 'votes': 14, 'id': 4334720}
# 3482   {'rating': 6.1, 'votes': 81, 'id': 4362764}
#
#                        countries   type  \
# 0                          [USA]  movie
# 1                          [USA]  movie
# 2                          [USA]  movie
# 3                          [USA]  movie
# 4                          [USA]  movie
# ...                          ...    ...
# 3478                    [Taiwan]  movie
# 3479                       [USA]  movie
# 3480                     [Japan]  movie
# 3481            [Brazil, France]  movie
# 3482  [Ethiopia, Spain, Finland]  movie
#
#                                                tomatoes  \
# 0     {'viewer': {'rating': 2.8, 'numReviews': 9}, '...
# 1     {'viewer': {'rating': 3.3, 'numReviews': 71, '...
# 2     {'viewer': {'rating': 3.6, 'numReviews': 75, '...
# 3     {'viewer': {'rating': 3.3, 'numReviews': 1390,...
# 4     {'viewer': {'rating': 3.6, 'numReviews': 87, '...
# ...                                                 ...
# 3478                                                NaN
# 3479                                                NaN
# 3480                                                NaN
# 3481                                                NaN
# 3482                                                NaN
#
#                                          plot_embedding   rated metacritic
# 0     [0.00072939653, -0.026834568, 0.013515796, -0....     NaN        NaN
# 1     [-0.022837115, -0.022941574, 0.014937485, -0.0...    TV-G        NaN
# 2     [0.00023330493, -0.028511643, 0.014653289, -0....     NaN        NaN
# 3     [-0.005927917, -0.033394486, 0.0015323418, -0....     NaN        NaN
# 4     [-0.0059373598, -0.026604708, -0.0070914757, -...  PASSED        NaN
# ...                                                 ...     ...        ...
# 3478                                                NaN     NaN        NaN
# 3479  [0.01443591, -0.014968648, -0.0077961707, -0.0...     NaN       47.0
# 3480  [0.006564625, -0.02858587, -0.01601545, 0.0004...     NaN        NaN
# 3481  [0.01314639, -0.011841122, 0.013581479, -0.028...     NaN        NaN
# 3482  [-0.0009377669, -0.021177763, -0.0052474686, -...     NaN        NaN
#
# [3483 rows x 23 columns]
